# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
iAstro_name = {"0":"牡羊座","1":"金牛座","2":"雙子座","3":"巨蟹座","4":"獅子座","5":"處女座",
              "6":"天秤座","7":"天蠍座","8":"射手座","9":"魔羯座","10":"水瓶座","11":"雙魚座"}

title = ["幸運數字","今日吉時","幸運顏色","開運方位","幸運星座","整體評分",
         "整體說明","愛情評分","愛情說明","事業評分","事業說明","財運評分","財運說明"]

dict_result = {}

date = "2020-02-18"
#iAstro = "0"

# %%
def web_scrapy(date,iAstro):
    temp_list = []
    url = "http://astro.click108.com.tw/daily_%d.php?iAstro=%d&iAcDay=%s"%(int(iAstro),int(iAstro),date)
    res = requests.get(url)
    #res.content
    soup = BeautifulSoup(res.text, "lxml")
    #print(soup.text)
    #print("日期 :",date)
    print("星座 :",iAstro_name[iAstro])
    #print("幸運數字 :",soup.findAll("div", class_="LUCKY")[0].text.split()[0])
    #print("今日吉時 :",soup.findAll("div", class_="LUCKY")[1].text.split()[0])
    #print("幸運顏色 :",soup.findAll("div", class_="LUCKY")[2].text.split()[0])
    #print("開運方位 :",soup.findAll("div", class_="LUCKY")[3].text.split()[0])
    #print("幸運星座 :",soup.findAll("div", class_="LUCKY")[4].text.split()[0])
    print("-----------")
    #dict_result=pd.DataFrame({"":title})

    for i,j in enumerate(soup.findAll("div", class_="LUCKY")):
        print(j.text.split()[0])
        temp_list.append(j.text.split()[0])

    for i,j in enumerate(soup.select("div.TODAY_CONTENT > p")):    
        if (i)%2 == 0:
            print(j.text[4:-1])
            temp_list.append(j.text[4:-1])
        else:
            print(j.text)
            temp_list.append(j.text)
            print()
    return temp_list

dict_result=pd.DataFrame({"":title})
for i in range(0,12,1):
    temp_list = web_scrapy(date,str(i))
    dict_result[iAstro_name[str(i)]] =  temp_list    
        
dict_result.to_csv("%s.csv"%(date),encoding="utf_8_sig",index=0)
# Out:
# 星座 : 牡羊座
# -----------
# 1
# 珠貝白
# 東南方向
# 2:00-3:00pm
# 雙魚座
# ★★☆☆☆
# 今天你很想表現自己的愛心，能善待身邊的每一個人，對伴侶也會表現出超乎尋常的關心。理財方面今天會受到小人的覬覦，但你穩重的表現讓對方產生一種睿智與豁達的感覺，似乎無從下手。
#
# ★★★☆☆
# 單身者想戀愛要做好心理準備，情路較為坎坷。喜歡的難追到，不喜歡的難拒絕。
#
# ★★☆☆☆
# 今天你只要按照自己的心意做事就好，強迫自己去幫助他人，反倒容易被誤會。
#
# ★★★☆☆
# 欠缺開源的企圖心，恐怕看得到金子卻拿不到金子。
#
# 星座 : 金牛座
# -----------
# 6
# 和闐玉白
# 正南方向
# 5:00-6:00am
# 雙子座
# ★☆☆☆☆
# 可多與朋友、同學聯絡，一起出遊或聚會，都是你贏得異性好感的途徑。今天開銷很大，有些不必要買的東西就省省，不要搞得財政狀況太過狼狽。工作中時常走神，想這想那的，很容易讓工作做不好。
#
# ★★☆☆☆
# 單身者遇到喜歡的人宜表現自然大方，過份在意反而容易弄巧成拙，驚飛愛情鳥唷！
#
# ★☆☆☆☆
# 事業運很不好，像洩氣皮球般，不太堆得動。想要混水摸魚時要小心點，可別露出馬腳囉！
#
# ★☆☆☆☆
# 財運波動性較大，容易因為迷糊或拖延而造成財物損失。注意今日是否有帳單到期，免得過期受罰！
#
# 星座 : 雙子座
# -----------
# 4
# 墨玉綠
# 正西方向
# 5:00-7:00pm
# 處女座
# ★★★☆☆
# 同性戀人今天面臨的外部壓力會很大，要多多的體諒彼此，只有兩個人一起承擔才能減輕很多心理負擔；手頭上該處理的任務在午後已完成得差不多，比較希望沒有新的任務下達；與以前同學一起聚聚，不但聯絡了感情，也有機會獲得寶貴的理財訊息。
#
# ★★★☆☆
# 對戀人或另一半的依賴較強，容易讓對方感到疲憊，應注意控制情緒，多為對方考慮。
#
# ★★★☆☆
# 情緒比較低落，常會躲近自己的世界獨自哀傷，有點自我憐憫的意味。
#
# ★★☆☆☆
# 金錢上有點小狀況，尤其是業務、主管級人物，特別容易產生業績、營運壓力。
#
# 星座 : 巨蟹座
# -----------
# 6
# 琉璃銀
# 正西方向
# 3:00-5:00pm
# 雙子座
# ★★★★☆
# 愛情順利，單身者選擇今天向追求一段時日的對象表白，易如願以償。財運一般，對金錢的敏銳度不太高，玩金錢遊戲易失算。晚上約上好友去歌劇院看看現場表演，會感覺輕鬆愉快，還有機會結識新朋友。
#
# ★★★★☆
# 愛情運旺旺，別板著臉，多點自然的微笑，愛神就會眷顧你喔！
#
# ★★★☆☆
# 事業運普通，心態上有點陰晴不定的傾向，時而開心積極，時而沉默緩慢，是個變化多端的工作天。
#
# ★★★☆☆
# 普通的一天，專心的工作吧，不適合處理或計劃財務問題！
#
# 星座 : 獅子座
# -----------
# 2
# 硃砂紅
# 西南方向
# 9:00-10:00am
# 牡羊座
# ★★★☆☆
# 愛情運弱，不要一味地要求另一半，越想掌控對方就逃得越快。從事娛樂業的人要提高服務質量，財運才會更好。工作平順，下午有機會收到好消息，對你的工作很有利。
#
# ★★☆☆☆
# 渴望戀愛的氣氛，可是太挑剔會招致反效果。
#
# ★★★☆☆
# 在交際方面的運勢不錯，有機會應常與朋友聯絡、互動，不僅會讓生活感覺輕鬆自在，還有助於尋求事業契機。
#
# ★★★☆☆
# 容易破財，有擺闊的傾向，送禮送紅包，高興得合不攏嘴，回頭摸摸荷包卻又後悔不已。
#
# 星座 : 處女座
# -----------
# 3
# 辣椒紅
# 東北方向
# 2:00-4:00pm
# 雙魚座
# ★★★★☆
# 愛情運不太妙，一點小的誤會也容易引起摩擦。不過還好，雖然愛情上有點小挫折，但豐厚的收入很容易讓你把不愉快拋諸腦後，買樂透也會有不錯的收穫。能順利完成工作任務，無後顧之憂。
#
# ★★★☆☆
# 單身者有機會與心儀的對象約會，若能在約會時精心打扮一番，會有加分作用。
#
# ★★★★☆
# 很有幹勁，工作熱情高漲，雖然會有許多繁瑣的任務，但你都能妥善處理。
#
# ★★★★☆
# 財運頗佳，今天適合業務往來、談判佣金問題，多能如願以償。
#
# 星座 : 天秤座
# -----------
# 5
# 可可棕
# 正北方向
# 11:00-12:00pm
# 射手座
# ★★★★★
# 裝扮上也不用太過追求潮流，只要穿出個人的品味與個性，就能吸引眾人的眼球。單身者參加團體聚會，會有不少異性主動地接近你，把握好機會就有希望獲得良緣哦。工作積極性高，迫不及待提出自己的見解，希望得到上司的認同。
#
# ★★★★☆
# 旺旺的愛情運，是個情話綿綿的大吉日。單身者不妨多參加團隊活動，可以提升愛情運唷！
#
# ★★★★☆
# 今日事業運還不錯，雖然忙碌了點，可是能獲得成就感以及正面的肯定！
#
# ★★★★☆
# 財富的獲得與競爭有關係，必須勤勞的耕耘與人競爭。對於頭銜大、職位高的人幫助較明顯。
#
# 星座 : 天蠍座
# -----------
# 0
# 象牙白
# 西南方向
# 5:00-6:00am
# 雙子座
# ★★☆☆☆
# 異性緣較弱，單身者有戀愛機會，但因朋友介入而讓感情難有進展。今天適合與家人在一起，閒聊或做家務都會讓你有收穫。領悟力強，能從父母的言語中受到一些啟發，對工作有利。
#
# ★★☆☆☆
# 與戀人相處會有一些小衝突，多微笑氣氛會得到緩和，多忍讓可讓關係更和諧。
#
# ★★★☆☆
# 今天別做職場的乖孩子，應敢於提不同意見，努力與上司站在同一高度看問題，有助於獲得上司的重用。
#
# ★★★☆☆
# 財運平順，有利於「動口生財」、「反應靈活」的族群。
#
# 星座 : 射手座
# -----------
# 8
# 杜鵑粉
# 東南方向
# 5:00-6:00pm
# 射手座
# ★★★☆☆
# 今天週遭纏繞著頗濃厚的戀愛氣息，若有親朋好友熱心為你介紹，一定不要害羞拒絕。財運方面適合賺取正財，投機取巧容易血本無歸，對於他人的小道消息別輕信。工作上有與人合作的機會，而且你能夠提出有創意的構想，易獲得好評。
#
# ★★★☆☆
# 別冷落了另一半，有時間不妨陪同伴侶去看一場浪漫的愛情電影，可讓感情迅速升溫。
#
# ★★★★☆
# 想要拼拼看的心理，會讓你超時工作，腦子馬不停蹄的思索如何佈局，也會主動尋覓新契機。
#
# ★★☆☆☆
# 財運有點小狀況，有金錢上的困擾，尤其是業務、主管級人物，特別容易產生業績營運壓力。
#
# 星座 : 魔羯座
# -----------
# 0
# 香吉士黃
# 東南方向
# 9:00-10:00pm
# 天秤座
# ★★★★☆
# 所謂樹大招風不無道理，工作上雖然有可喜的成績，但謙虛謹慎才能更長久。對理財有獨到的眼光，頗能抓住機遇進行投資。查閱一些有關聯的科技資訊，對判斷投資的方向起到決定性的作用。
#
# ★★★★☆
# 魅力四射的一天，異性緣很好，有許多機會跟異性朋友談天喝茶。
#
# ★★★★☆
# 事業運佳，適合做點創意設計、文書計算、研究分析型的工作，居多會達到不錯的效果。
#
# ★★★★☆
# 能運籌帷幄，合理利用所有的資金，使每一分錢都能發揮最大的作用。
#
# 星座 : 水瓶座
# -----------
# 6
# 翡翠綠
# 正南方向
# 12:00-1:00pm
# 雙子座
# ★★☆☆☆
# 與普通異性關係能保持在很恰當的位置，與戀人的關係也很穩定；下班前會有突如其來的事情需要臨時處理，造成心情煩躁，平和對待便能順利完成；與久為聯繫的朋友通上電話，勾起許多往日的回憶，讓你很開心。
#
# ★★★☆☆
# 戀愛中人約會增多，時常與戀人沉浸在浪漫的氣氛中；已婚者容易在錢財上起爭執。
#
# ★★★☆☆
# 情感豐富，容易有不錯的創意，不妨擬訂企劃案或搞創作，易有成果。
#
# ★★★☆☆
# 得財略為費心，支出頗多。
#
# 星座 : 雙魚座
# -----------
# 9
# 古銅青
# 正北方向
# 7:00-8:00pm
# 牡羊座
# ★★★☆☆
# 工作運佳，適合單獨作業，能嚴格要求自己，工作效率高。若與他人合作，易因意見不同而難以進行。在與人溝通時，注意態度，太生硬容易招人反感。單身者有機會與舊情人相遇，產生別樣情愫。
#
# ★★★☆☆
# 多動腦可提升戀愛運，親手製作一些手工藝品送給伴侶，雙方都會有新鮮的體驗喔！
#
# ★★★★☆
# 運勢旺盛，行動力強，有機會在同事面前一展身手，對你的事業進展大有幫助哦！
#
# ★★☆☆☆
# 把重心放在其他事情上面吧，不要在意金錢問題，對於理財上面的小道消息最好經過求證再吸收。

# %%
dict_result.to_json("json%s.json"%(date),orient='table',force_ascii=False)
